# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 2.6: Practice with Data Collections*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI614/blob/main/Week%202/Notebook2.6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# uses the New York taxi in order to understand when people tip their taxi drivers more generously with the customary tip between 15% and 20%.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
# Import the taxi info from both January and July 2019.
# Include the following columns: tpep_pickup_datetime, passenger_count, trip_distance,
# fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge,
# total_amount, and congestion_surcharge.

filenames = ['C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01aa.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01aq.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01bg.csv',
             'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ap.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ab.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ar.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07aa.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07aq.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ac.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01as.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ab.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ar.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ad.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01at.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ac.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07as.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ae.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01au.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ad.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07at.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01af.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01av.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ae.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07au.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ag.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01aw.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07af.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07av.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ah.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ax.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ag.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07aw.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ai.csv', 
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ay.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ah.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ax.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01aj.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01az.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ai.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ay.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ak.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ba.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07aj.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07az.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01al.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01bb.csv', 
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ak.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ba.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01am.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01bc.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07al.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07bb.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01an.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01bd.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07am.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ao.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01be.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07an.csv',
            'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01ap.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-01bf.csv', 'C:/Users/bay/Desktop/sandbox/DS sandbox/AAI614/Week 2/nyc_taxi/nyc_taxi_2019-07ao.csv']

all_dfs = [pd.read_csv(one_filename) for one_filename in filenames]

df = pd.concat(all_dfs)


df.head()
# Out:
# C:\Users\bay\AppData\Local\Temp\ipykernel_9772\3769871016.py:28: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_dfs = [pd.read_csv(one_filename) for one_filename in filenames]
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1       1.0  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2       2.0  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3       2.0  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4       2.0  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N         151.0         239.0
# 1            2.6         1.0                  N         239.0         246.0
# ...

# %%
# Create a new column, pre_tip_amount
df['pre_tip_amount'] = (
    df[['fare_amount','extra','mta_tax','tolls_amount','improvement_surcharge','congestion_surcharge']]
    .sum(axis='columns')
)

df.head()
# Out:
# C:\Users\bay\AppData\Local\Temp\ipykernel_9772\1398773753.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['pre_tip_amount'] = (
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1       1.0  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2       2.0  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3       2.0  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4       2.0  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N         151.0         239.0
# ...

# %%
# Create a new column, tip_percentage, showing the percent of the fare_amount that poeple tipped
df['tip_percentage'] = df['tip_amount'] / df['pre_tip_amount']

df.head()
# Out:
# C:\Users\bay\AppData\Local\Temp\ipykernel_9772\230160475.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['tip_percentage'] = df['tip_amount'] / df['pre_tip_amount']
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1       1.0  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2       2.0  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3       2.0  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4       2.0  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
# What was the overall tip percentage?
df['tip_percentage'].mean()
# Out:
# 0.11954232412352621

# %%
# How many times did people tip more than 100%?
(df['tip_percentage'] > 1).value_counts()
# Out:
# tip_percentage
# False    13977856
# True          353
# Name: count, dtype: int64

# %%
# What percent of taxi riders give no tip at all?
(df['tip_percentage'] == 0).value_counts(normalize=True)
# Out:
# tip_percentage
# False    0.987561
# True     0.012439
# Name: proportion, dtype: float64

# %%
# On which day of the week do people tip the greatest percentage?
# Mon = 0, Tues = 1, Wed = 2, Thu = 3, Fri = 4, Sat = 5, Sun = 6
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'], errors='coerce')
df.groupby(df['tpep_pickup_datetime'].dt.day_of_week)['tip_percentage'].mean().sort_values(ascending=False)
# Out:
# tpep_pickup_datetime
# 2.0    0.130667
# 1.0    0.119567
# 0.0    0.116898
# 6.0    0.106113
# 3.0    0.000000
# 4.0    0.000000
# Name: tip_percentage, dtype: float64

# %%
# At which hour do people tip the greatest percentage?
df.groupby(df['tpep_pickup_datetime'].dt.hour)['tip_percentage'].mean().sort_values(ascending=False)
# Out:
# tpep_pickup_datetime
# 2.0     0.135977
# 5.0     0.135149
# 8.0     0.127069
# 19.0    0.125081
# 20.0    0.124281
# 22.0    0.123341
# 21.0    0.122900
# 9.0     0.122312
# 1.0     0.122199
# 7.0     0.121403
# 3.0     0.120824
# 0.0     0.120553
# 18.0    0.120328
# 17.0    0.115551
# 16.0    0.114583
# 23.0    0.114106
# 12.0    0.113474
# 10.0    0.113438
# 15.0    0.113172
# 6.0     0.112851
# 4.0     0.112616
# 14.0    0.111711
# 13.0    0.111327
# 11.0    0.111262
# Name: tip_percentage, dtype: float64

# %%
# Do people tip more, on average, in January or July?
df.groupby(df['tpep_pickup_datetime'].dt.month)['tip_percentage'].mean().sort_values(ascending=False)
# Out:
# tpep_pickup_datetime
# 2.0     0.358127
# 1.0     0.122165
# 12.0    0.116987
# 7.0     0.116844
# 6.0     0.105198
# 11.0    0.000000
# Name: tip_percentage, dtype: float64

# %%
# What was the 1-day period in our data set when people tipped the greatest percentage?
df = df.set_index('tpep_pickup_datetime')
df.resample('1D')['tip_percentage'].mean().sort_values(ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[18], line 2
#       1 # What was the 1-day period in our data set when people tipped the greatest percentage?
# ----> 2 df = df.set_index('tpep_pickup_datetime')
#       3 #df.resample('1D')['tip_percentage'].mean().sort_values(ascending=False).head(10)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6128, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6125     frame = self
#    6126 else:
#    6127     # GH 49473 Use "lazy copy" with Copy-on-Write
# -> 6128     frame = self.copy(deep=None)
#    6130 arrays: list[Index] = []
#    6131 names: list[Hashable] = []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6811, in NDFrame.copy(self, deep)
#    6662 @final
# ...

# %%
# Try again, within our range
df = df.sort_index()

df = pd.concat([df.loc['2019-01-01':'2019-01-31'],
           df.loc['2019-07-01':'2019-07-31']])

df.resample('1D')['tip_percentage'].mean().sort_values(ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Try again, within our range
# ----> 2 df = df.sort_index()
#       4 df = pd.concat([df.loc['2019-01-01':'2019-01-31'],
#       5            df.loc['2019-07-01':'2019-07-31']])
#       7 df.resample('1D')['tip_percentage'].mean().sort_values(ascending=False).head(10)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:7379, in DataFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    7282 def sort_index(
#    7283     self,
#    7284     *,
#    (...)
#    7293     key: IndexKeyFunc | None = None,
#    7294 ) -> DataFrame | None:
#    7295     """
#    7296     Sort object by labels (along an axis).
#    7297
#    (...)
#    7377     d  4
#    7378     """
# -> 7379     return super().sort_index(
# ...

# %%
df.resample('1M')['tip_percentage'].mean().dropna()
# Out:
# C:\Users\bay\AppData\Local\Temp\ipykernel_9772\497147689.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample('1M')['tip_percentage'].mean().dropna()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.resample('1M')['tip_percentage'].mean().dropna()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:9771, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    9768 else:
#    9769     convention = "start"
# -> 9771 return get_resampler(
#    9772     cast("Series | DataFrame", self),
#    9773     freq=rule,
#    9774     label=label,
#    9775     closed=closed,
#    9776     axis=axis,
#    9777     kind=kind,
#    9778     convention=convention,
#    9779     key=on,
# ...

# %% [markdown]
# # Questions

# %% [markdown]
# 1. We saw that 32 percent of riders don't tip at all. Of those who *do*, what percentage do they tip, on average?

# %% [markdown]
# 2. How many of the rides in our data set, supposedly from January and July 2019, are from outside of those dates?

# %% [markdown]
# 3. Looking only at dates in January and July, on what week did passengers tip the greatest percentage?
